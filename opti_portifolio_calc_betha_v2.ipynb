# %%
#!/usr/bin/env python3
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style

# seria interessante ter uma selecao das acoes pra escolher, com bastante variedade
# e arrumar algum jeito de fazer as regras de quantias máximas ou mínimas para os tipos
# diferentes das acoes, por exemplo, 30% de energia, 30% de bancos e 40% tecnologias...

testCSV = './test_market_returns_brl.csv'
stockRows = 1243
stockCols = 63

dfStock = pd.read_csv(testCSV, nrows=stockRows)
dfStock.head()
# Out:
#          Date    ^BVSP   ABEV3.SA  ASAI3.SA  AZUL4.SA  B3SA3.SA   BBSE3.SA  \
# 0  2017-01-02  59589.0  13.968292       NaN       NaN  4.515615  18.234648
# 1  2017-01-03  61814.0  14.250913       NaN       NaN  4.701455  18.883545
# 2  2017-01-04  61589.0  14.139578       NaN       NaN  4.790214  19.480005
# 3  2017-01-05  62071.0  14.216655       NaN       NaN  4.731965  19.086735
# 4  2017-01-06  61665.0  14.096756       NaN       NaN  4.729191  18.791780
#
#     BBDC4.SA   BBDC3.SA  BRAP4.SA  ...   QUAL3.SA   RADL3.SA  RAIL3.SA  \
# 0  11.856694  12.102320  7.427600  ...  14.848257  11.654523      6.11
# 1  12.358868  12.592777  7.740072  ...  15.495207  12.100480      6.18
# 2  12.280593  12.588573  7.571030  ...  15.629331  11.929400      6.18
# 3  12.416537  12.660000  7.950093  ...  15.534655  11.750633      6.19
# 4  12.494811  12.756644  7.811786  ...  15.376862  11.775620      6.35
#
#     SBSP3.SA  TOTS3.SA   UGPA3.SA  USIM5.SA   VALE3.SA  WEGE3.SA   YDUQ3.SA
# 0  24.308306  7.483278  29.983891  3.654238  18.692446  5.076362  13.344676
# 1  24.591063  7.867117  30.469639  3.842324  19.520405  5.331861  14.087488
# 2  25.302233  7.819534  29.983891  4.075193  19.169830  5.204111  14.018389
# 3  25.370777  7.860775  30.160522  4.119975  19.900818  5.190664  13.793818
# 4  25.002340  7.616511  30.028051  4.003540  19.371222  5.234367  13.690170
#
# [5 rows x 65 columns]

# %%
# cleaning the data

dfStock = dfStock.dropna(axis=0)
stockData = dfStock.iloc[0:, 2:]
marketData = dfStock.iloc[0:, [1]]
# stockData = stockData.dropna(axis=0)
# stockData.head()

# update das cols e rows depois da limpeza
[stockRows, stockCols] = stockData.shape
# print(stockRows, stockCols)
# [marketRows, marketCols]=marketData.shape
# print(marketRows, marketCols)

# %%
def getCompoundReturnLog(stockData):   
    # stockReturn = np.zeros([Rows-1, Columns])
    returns = np.log(stockData/stockData.shift(1)).dropna(how="any")

    return np.asarray(returns)

# %%
# pegando as labels das stocks
stockLabels = dfStock.columns[2:stockCols + 1].tolist()

# stockPricesArr = np.asarray(stockData)
# [rows, cols] = stockPricesArr.shape

# compute stock returns
stockReturnsArr = getCompoundReturnLog(stockData)


# compute market returns
# marketPricesArr = np.asarray(marketData)
# [mRows, mCols] = marketPricesArr.shape
marketReturnsArr = getCompoundReturnLog(marketData)


# stockReturnsArr
print(stockReturnsArr)
print(marketReturnsArr)

# provavelmente a única diferença é tornar um array antes de retornar, ai mantem o que tava sendo feito antes
# Out:
# [[ 0.01585041  0.01528876 -0.03196615 ...  0.03027645 -0.01212467
#   -0.02967363]
#  [ 0.01278431 -0.01669019 -0.005947   ... -0.01237936 -0.00077882
#   -0.00755802]
#  [ 0.04214784  0.02629902 -0.00155726 ... -0.01495939 -0.05020011
#    0.        ]
#  [-0.03853782]
#  [ 0.01703032]
#  [-0.00936226]
#  [ 0.01836282]
#  [-0.00191758]
#  [-0.00966952]
#  [-0.01109001]
#  [-0.02091244]
#  [-0.02356169]
#  [ 0.01283485]
#  [ 0.01826305]
#  [ 0.01574613]
#  [-0.00687058]
#  [ 0.00264473]
#  [-0.03092684]
#  [ 0.0088867 ]
#  [-0.00115271]
#  [ 0.01716148]
#  [-0.02245575]
#  [ 0.00058863]
#  [ 0.000923  ]
#  [ 0.0002261 ]
#  [ 0.02012439]
#  [-0.00580413]
#  [ 0.01131037]
#  [-0.00239145]
#  [ 0.01284292]
#  [-0.00192076]
#  [-0.0333659 ]
#  [ 0.00102051]
#  [-0.0279259 ]
#  [-0.01344685]
#  [ 0.02250212]
#  [-0.02133625]
#  [-0.00053576]
#  [-0.00620558]
#  [-0.02107092]
#  [ 0.01961297]
#  [ 0.00062509]
#  [-0.02109833]
#  [ 0.01356174]
#  [-0.0004103 ]
#  [ 0.00717019]
#  [ 0.00409451]
#  [ 0.01644452]
#  [-0.01320352]
#  [-0.01711454]
#  [-0.01506876]
#  [-0.00409795]
#  [ 0.00497182]
#  [-0.00890056]
#  [ 0.01497708]
#  [ 0.00817578]
#  [ 0.01233345]
#  [-0.034488  ]
#  [ 0.00575505]
#  [-0.0087824 ]
#  [-0.01124882]
#  [ 0.03597135]
#  [ 0.00576514]
#  [ 0.01688341]
#  [ 0.00652003]
#  [ 0.00498948]
#  [-0.01683911]
#  [ 0.01370736]
#  [-0.00348609]
#  [-0.00581856]
#  [ 0.00569749]
#  [ 0.00781145]
#  [-0.00938669]
#  [-0.02055477]
#  [ 0.00456014]
#  [-0.00242949]
#  [-0.00335975]
#  [ 0.00608303]
#  [-0.00634048]
#  [-0.00724506]
#  [ 0.00684446]]

# %%
# calculo do beta pras stocks
beta = []
marketVar = np.var(marketReturnsArr, ddof=1)

for i in range(63):
    CovarMat = np.cov(marketReturnsArr[:,0], stockReturnsArr[:, i ])
    Covar  = CovarMat[1,0]
    beta.append(Covar/marketVar)
    
#display results
print('Asset Betas:\n')
for data in beta:
    print('{:9.3f}'.format(data))
    
print(len(beta))
# Out:
# Asset Betas:
#
#     0.782
#     0.704
#     1.753
#     1.257
#     0.733
#     1.166
#     1.173
#     0.558
#     1.016
#     1.150
#     0.729
#     0.788
#     0.988
#     1.712
#     0.676
#     0.960
#     0.637
#     1.939
#     1.643
#     1.280
#     1.183
#     1.114
#     1.481
#     0.546
#     0.822
#     0.959
#     0.760
#     1.642
#     0.749
#     0.964
#     0.943
#     1.651
#     0.985
#     0.912
#     0.821
#     0.942
#     0.936
#     1.113
#     0.367
#     1.486
#     0.416
#     1.226
#     1.307
#     1.180
#     1.582
#     0.168
#     0.543
#     1.393
#     1.252
#     1.055
#     1.197
#     1.229
#     1.219
#     0.948
#     0.678
#     1.007
#     0.794
#     0.946
#     1.418
#     1.419
#     0.802
#     0.720
#     1.444
# 63

# %%
# consideramos que as stocks com Beta > 1 são as mais voláteis, temos a seguinte separação entre elas
beta_12_stocks = [0.779, 0.703, 1.743, 1.250, 0.734, 1.168, 1.173, 0.639, 1.016, 1.157, 0.730, 0.784]
beta_20_32_stocks = [1.649, 1.280, 1.177, 1.109, 1.496, 0.547, 0.822, 0.958, 0.764, 1.646, 0.747, 0.971]
